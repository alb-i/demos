# %%
import pandas as pd
from datetime import date
import numpy as np

# %%
prep = pd.read_csv("data/prep.csv",index_col=0)
prep
# Out:
#         year  month carrier          carrier_name airport  \
# 0       2022      3      9E     Endeavor Air Inc.     ABE
# 1       2022      3      9E     Endeavor Air Inc.     ABY
# 2       2022      3      9E     Endeavor Air Inc.     AEX
# 3       2022      3      9E     Endeavor Air Inc.     AGS
# 4       2022      3      9E     Endeavor Air Inc.     ALB
# ...      ...    ...     ...                   ...     ...
# 317694  2003      6      DL  Delta Air Lines Inc.     SEA
# 317695  2003      6      DL  Delta Air Lines Inc.     SFO
# 317696  2003      6      DL  Delta Air Lines Inc.     SJC
# 317697  2003      6      DL  Delta Air Lines Inc.     SJU
# 317698  2003      6      DL  Delta Air Lines Inc.     SLC
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        135.0
# 1                  Albany, GA: Southwest Georgia Regional         79.0
# ...

# %%
monthSums = prep.groupby([prep.t,prep.carrier,prep.carrier_name,prep.month,prep.year,prep.covid,prep.control,prep.extra_mon,prep.extra_tue,prep.extra_wed,prep.extra_thu,prep.extra_fri,prep.extra_sat,prep.extra_sun,prep.top30,prep.fulldata,prep.mon_ct,prep.tue_ct,prep.wed_ct,prep.thu_ct,prep.fri_ct,prep.sat_ct,prep.sun_ct]).sum()

monthSums.to_csv('data/sum-months-carrier.csv')

# %%
monthSums
# Out:
#                                                                                                                                                                                                    arr_flights  \
# t   carrier carrier_name           month year covid control extra_mon extra_tue extra_wed extra_thu extra_fri extra_sat extra_sun top30 fulldata mon_ct tue_ct wed_ct thu_ct fri_ct sat_ct sun_ct
# 1   AA      American Airlines Inc. 6     2003 0     0       1         0         0         0         0         0         1         0     0        5      4      4      4      4      4      5           18860.0
#                                                                                                                                   1     0        5      4      4      4      4      4      5           43418.0
# ...
