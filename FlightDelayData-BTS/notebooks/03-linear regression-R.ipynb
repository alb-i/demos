# %%
version
# Out:
#                _
# platform       x86_64-conda-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          4
# minor          1.2
# year           2021
# month          11
# day            01
# svn rev        81115
# language       R
# version.string R version 4.1.2 (2021-11-01)
# nickname       Bird Hippie

# %%
data <- read.csv("fixg.csv")
data
# Out:
#       year month carrier carrier_name         airport
# 1     2009 11    AS      Alaska Airlines Inc. DCA
# 2     2009 11    AS      Alaska Airlines Inc. DEN
# 3     2009 11    AS      Alaska Airlines Inc. DFW
# 4     2009 11    AS      Alaska Airlines Inc. EWR
# 5     2009 11    AS      Alaska Airlines Inc. HNL
# 6     2009 11    AS      Alaska Airlines Inc. IAH
# 7     2009 11    AS      Alaska Airlines Inc. LAS
# 8     2009 11    AS      Alaska Airlines Inc. LAX
# 9     2009 11    AS      Alaska Airlines Inc. MCO
# 10    2009 11    AS      Alaska Airlines Inc. MIA
# 11    2009 11    AS      Alaska Airlines Inc. MSP
# 12    2009 11    AS      Alaska Airlines Inc. ORD
# 13    2009 11    AS      Alaska Airlines Inc. PDX
# 14    2009 11    AS      Alaska Airlines Inc. PHX
# 15    2009 11    AS      Alaska Airlines Inc. SAN
# 16    2009 11    AS      Alaska Airlines Inc. SEA
# 17    2009 11    AS      Alaska Airlines Inc. SFO
# 18    2009 11    B6      JetBlue Airways      BOS
# ...

# %%
colnames(data)
# Out:
#  [1] "year"                "month"               "carrier"
#  [4] "carrier_name"        "airport"             "airport_name"
#  [7] "arr_flights"         "arr_del15"           "carrier_ct"
# [10] "weather_ct"          "nas_ct"              "security_ct"
# [13] "late_aircraft_ct"    "arr_cancelled"       "arr_diverted"
# [16] "arr_delay"           "carrier_delay"       "weather_delay"
# [19] "nas_delay"           "security_delay"      "late_aircraft_delay"

# %%
m <- lm(arr_flights ~ year + as.factor(month),data)

# %%
summary(m)
# Out:
# Call:
# lm(formula = arr_flights ~ year + as.factor(month), data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1159.2  -856.9  -643.9  -138.8 20870.0
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -23073.470   2714.365  -8.501   <2e-16 ***
# year                   11.960      1.349   8.864   <2e-16 ***
# as.factor(month)2     -69.556     34.036  -2.044   0.0410 *
# as.factor(month)3      60.247     34.031   1.770   0.0767 .
# as.factor(month)4      -3.147     34.084  -0.092   0.9264
# as.factor(month)5      12.238     34.083   0.359   0.7195
# as.factor(month)6      21.999     33.579   0.655   0.5124
# as.factor(month)7      74.509     33.614   2.217   0.0267 *
# as.factor(month)8      69.188     33.587   2.060   0.0394 *
# as.factor(month)9     -18.053     33.614  -0.537   0.5912
# as.factor(month)10     31.982     33.668   0.950   0.3422
# as.factor(month)11    -22.527     33.597  -0.671   0.5025
# ...

# %%
plot(m)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
june2020 <- data[data$year == 2020 & data$month == 6,]

# %%
sum(june2020$arr_flights)
# Out:
# [1] 138034

# %%
sum(june2020$arr_del15) # ?? is this the number of planes that have been delayed, but less than 15 minutes?
# Out:
# [1] 8554

# %%
colSums(june2020[-c(1:6)])
# Out:
#         arr_flights           arr_del15          carrier_ct          weather_ct
#           138034.00             8554.00             3679.79              572.18
#              nas_ct         security_ct    late_aircraft_ct       arr_cancelled
#             2699.41               29.62             1573.03              402.00
#        arr_diverted           arr_delay       carrier_delay       weather_delay
#              211.00           509572.00           254767.00            42516.00
#           nas_delay      security_delay late_aircraft_delay
#            94376.00             1206.00           116707.00

# %%
sum(june2020$arr_flights)-sum(june2020$carrier_ct)-sum(june2020$weather_ct)-sum(june2020$nas_ct)-sum(june2020$security_ct)-sum(june2020$late_aircraft_ct)-sum(june2020$arr_cancelled)-sum(june2020$arr_diverted)
# Out:
# [1] 128867

# %%
-sum(june2020$carrier_ct)-sum(june2020$weather_ct)-sum(june2020$nas_ct)-sum(june2020$security_ct)-sum(june2020$late_aircraft_ct)
# Out:
# [1] -8554.03
